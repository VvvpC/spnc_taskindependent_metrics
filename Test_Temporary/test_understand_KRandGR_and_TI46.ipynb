# %% [markdown]
# 这个文档是帮助我探索和理解KRandGR(CQ)的指标与储层任务表现(NARMA10 and TI46)的失配的原因。
# 问题：利用当前'KRandGR'方法评估的储层配置在执行基准任务时展现了非常糟糕的表现，比如对于输出冻结（即在NARMA10中对于不同的输入的反馈都一致，并且数值的方差非常小，与目标值相距甚远）等。
# 假设：我认为KRandGR的评估标准和任务需求的标准不是同一回事，根源可能是我的代码问题，也可能是指标本身不统一的问题。
